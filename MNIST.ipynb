# %% [markdown]
# <a href="https://colab.research.google.com/github/rotoncsedu/DL/blob/main/MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.datasets import mnist
(train_img, train_labels), (test_img, test_labels) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
train_img.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
len(test_labels)
# Out:
# 10000

# %%
from tensorflow import keras
from tensorflow.keras import  layers

# %%
model = keras.Sequential([
    layers.Dense(512,activation="relu"),
    layers.Dense(10,activation="softmax")
])

# %%
model.compile(
    optimizer = "rmsprop",
    loss = "sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)

# %%
test_img = test_img.reshape((10000,28*28))
test_img = test_img.astype("float32") / 255
train_img = train_img.reshape((60000,28*28))
train_img = train_img.astype("float32") / 255

# %%
test_img.shape
# Out:
# (10000, 784)

# %%
train_img.ndim
# Out:
# 2

# %%
model.fit(train_img,train_labels,epochs=5,batch_size = 128)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9243 - loss: 0.2620
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9689 - loss: 0.1072
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9790 - loss: 0.0708
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9851 - loss: 0.0502
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9887 - loss: 0.0374

# %%
test_digits = test_img[0:10]
pred = model.predict(test_digits)
pred[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# array([3.21166063e-08, 1.09338165e-08, 2.26361863e-05, 6.89873341e-05,
#        2.67580784e-11, 3.36641399e-08, 1.50363901e-12, 9.99906719e-01,
#        4.43639408e-07, 1.10342216e-06], dtype=float32)

# %%
pred[0].argmax()
# Out:
# np.int64(7)

# %%
pred[0][7]
# Out:
# np.float32(0.9999067)

# %%
test_labels[0]
# Out:
# np.uint8(7)

# %%
pred[5].argmax()
# Out:
# np.int64(1)

# %%
test_labels[5]
# Out:
# np.uint8(1)

# %%
pred[8].argmax()
# Out:
# np.int64(5)

# %%
test_labels[8]
# Out:
# np.uint8(5)

# %%
test_loss, test_acc = model.evaluate(test_img,test_labels)
print(f"test_acc: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9803 - loss: 0.0595
# test_acc: 0.9803000092506409
